# %% [markdown]
# # 1. 颜色和RGBA值

# %% [markdown]
# ## 颜色表

# %%
from IPython.display import Image as img

img(filename='data/color.png')

# %% [markdown]
# ## 使用 pillow 解析 标准颜色 RGBA 值

# %% [markdown]
# ### 红色 RGBA值

# %%
from PIL import ImageColor

# 红色的标准值
ImageColor.getcolor('red', 'RGBA')
# Out:
# (255, 0, 0, 255)

# %% [markdown]
# ### 蓝色 RGBA 值

# %%
ImageColor.getcolor('blue', 'RGBA')
# Out:
# (0, 0, 255, 255)

# %% [markdown]
# ### 绿色 RGBA 值

# %%
ImageColor.getcolor('green', 'RGBA')
# Out:
# (0, 128, 0, 255)

# %% [markdown]
# # 2. 坐标系和 BOX 元组

# %% [markdown]
# ## 图像坐标轴范围确定像素位置

# %%
from IPython.display import Image as img
img(filename='data/pix.png')

# %% [markdown]
# ## Pillow如何确立一个像素块

# %%
img(filename='data/block.png')

# %% [markdown]
# > 元组（3, 1, 9, 6）表示图 17-2 中的所有像素 <br>
# > 要求是左上的(x,y) 和 右下的(x,y)
